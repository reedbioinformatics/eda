# %%
#importing libraries and setup

# %%
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
import scipy.spatial.distance as ssd
import scipy as sp

# %%
x_train = np.array([[ 1., -1., 2., 5],
[ 2., 0., 0., 4],
[ 0., 1., -1., 1]])

# %%
#Simple Statistics

# %%
x_train.mean(axis=0)
# Out:
# array([1.        , 0.        , 0.33333333, 3.33333333])

# %%
x_train.std(axis=0)
# Out:
# array([0.81649658, 0.81649658, 1.24721913, 1.69967317])

# %%
x_train.mean(axis=1)
# Out:
# array([1.75, 1.5 , 0.25])

# %%
x_train.std(axis=1)
# Out:
# array([2.16506351, 1.6583124 , 0.8291562 ])

# %%
#axis =0, denotes find the mean along the columns, axis=1 mean along the rows.

# %%
#Simple graphs

# %%
print(x_train[0,:]) #remember parentheses for print function
# Out:
# [ 1. -1.  2.  5.]

# %%
plt.plot(x_train[0,:])

# %%
plt.plot(x_train[0,:])
plt.plot(x_train[1,:],'r')

# %%
plt.plot(x_train[0,:])
plt.plot(x_train[1,:],'r')
plt.plot(x_train[2,:],)

# %%
#Simple graphs-b: Boxplot

# %%
plt.figure(2)

# %%
plt.figure(2)
plt.boxplot(x_train.transpose())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x182f9bad400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x182f9bad9a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x182f9bad130>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x182f9badf40>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x182f9a39250>,
# ...
#  'means': []}

# %%
x=np.random.random(10)/10
y=np.random.random(10)

# %%
b=np.stack((x,y))

# %%
plt.boxplot(b.T)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x182f9aacc70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x182f9abc250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x182f9aac9a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x182f9abc7f0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x182f9abcac0>,
# ...
#  'means': []}

# %%
#What do the plots denote?: Plot 1 ....Plot 2

# %%
#Data preprocessing When we are some data, and before it is fed into a model, 
#we need to do some transformations:
#Normalize the data so that they are with zero mean, and variance one. 
#Τhis is often needed by later stages in data mining

# %%
from sklearn import preprocessing
import numpy as np

# %%
x_train = np.array([[ 1., -1., 2., 5],
[ 2., 0., 0., 4],
[ 0., 1., -1., 1]])

# %%
#normalizing data makes it standard, there's a formula

# %%
x_scaled = preprocessing.scale(x_train)

# %%
#How do you normalize the data ln24?

# %%
#Bar-charts histograms

# %%
x=np.arange(1,11)
y=np.random.rand(100000)
z=np.random.randn(100000)
resX=np.histogram(y)
resZ=np.histogram(z)

# %%
plt.figure(3)
plt.bar(x, resX[0])
plt.figure(4)
plt.bar(x, resZ[0])
# Out:
# <BarContainer object of 10 artists>

# %%
#The two charts are showing differing distributions, 
#Chart 1 has values that appear equally distributed around the x-value 5
#minimal variabilty in Chart 1
#Chart 2 is a normal distribution

# %%
#Distances

# %%
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
import scipy.spatial.distance as ssd
import scipy as sp

# %%
x_train = np.array([[ 1., -1., 2., 5],
[ 2., 0., 0., 4],
[ 0., 1., -1., 1]])
dst = ssd.euclidean (x_train[0,:],x_train[1,:])

# %%
x_train = np.array([[ 1., -1., 2., 5],
[ 2., 0., 0., 4],
[ 0., 1., -1., 1]])
dst = ssd.euclidean (x_train[0,:],x_train[1,:])
# Out:
#   File "C:\Users\Pam\AppData\Local\Temp\ipykernel_15720\3763380503.py", line 1
#     print "x_train"
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("x_train")?

# %%
print (x_train)
# Out:
# x_train

# %%
print (x_train)
# Out:
# [[ 1. -1.  2.  5.]
#  [ 2.  0.  0.  4.]
#  [ 0.  1. -1.  1.]]
